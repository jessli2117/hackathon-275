# %% [markdown]
# ## Webscraping

# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %% [markdown]
# ### Scraping Billboard's Top (<=50) Country Songs per Year (on 5-21-YYYY) from 1959-2019

# %%
# Getting the URL to request the data from
def change_url(first_year):
    return "https://www.billboard.com/charts/country-songs/"+str(year)+"-05-25"

# %%
## Webscraping and Cleaning
songs = ""
for year in range(1959,2020): # iterate through all the years
    url = change_url(year)
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    ranks = len(soup.select("[class~=chart-list-item]"))
    for rank in range(0,ranks):
        current_song = str(soup.select("[class~=chart-list-item]")[rank])
        current_song = current_song.split('>')[0].split("<div class")[1:]
        
        for i in range(0,len(current_song)): # all the different columns/descriptors
            descrip = current_song[i].replace('\"',"")
            descrip = current_song[i].split('data-')[1:]
            # cleaning each aspect of a column
            for element in range(0,len(descrip)):
                no_tags = descrip[element].split('=')[1].replace(",", " ")
                songs += str(no_tags) + ","
            songs = songs.replace('\"',"")
            songs += str(year) + "\n"
    
# add column names to dataset
columns = "artist,data-has-content,rank,song,year\n"   
songs = columns+songs

# %%
## Read songs into a long csv
outF = open("billboard_songs_artists_years.csv", "w")
outF.write(songs)
outF.close()

# %%
## Make it into a DataFrame to be able to analyze the data
df = pd.read_csv("billboard_songs_artists_years.csv")
df = df.drop(columns=["data-has-content"])

## Remove all of the whitespaces
df['artist'] = df['artist'].str.strip()
df['song'] = df['song'].str.strip()
#df['artist'] = df.apply(lambda x: ' '.join([w for w in  x['artist'].str.split(' ') if ('&' not in w) or (w != 'and') or (w != 'And')]))
df['artist'] = df['artist'].str.split(' ')
df['artist'] = df['artist'].map(lambda x: [w for w in x if (('&' not in w) and  (w != 'and') and (w != 'And'))])
df['artist'] = df['artist'].map(lambda x: ' '.join(x))
df['artist'] = df['artist'].str.split('/')
df['artist'] = df['artist'].map(lambda x: ' '.join(x))
df['song'] = df['song'].str.strip()
df.head(10)
# Out:
#            artist  rank                                               song  \
# 0   Johnny Horton     1                          The Battle Of New Orleans
# 1    George Jones     2                                    White Lightning
# 2      Jim Reeves     3                                               Home
# 3   George Morgan     4                                  I'm In Love Again
# 4       Ray Price     5                           Heartaches By The Number
# 5     Webb Pierce     6                               A Thousand Miles Ago
# 6  Frankie Miller     7                                  Black Land Farmer
# 7   Skeeter Davis     8                                       Set Him Free
# 8     Johnny Cash     9                           Luther Played The Boogie
# 9   Johnny Horton    10  When It's Springtime In Alaska (It's Forty Below)
#
#    year
# 0  1959
# 1  1959
# 2  1959
# 3  1959
# 4  1959
# 5  1959
# 6  1959
# 7  1959
# 8  1959
# 9  1959

# %%
## List all of the unique country artists
all_artists = df['artist'].unique()
all_artists[0:50]
# len(all_artists)
# Out:
# array(['Johnny Horton', 'George Jones', 'Jim Reeves', 'George Morgan',
#        'Ray Price', 'Webb Pierce', 'Frankie Miller', 'Skeeter Davis',
#        'Johnny Cash', 'Carl Belew', 'Margie', 'Ernest Tubb', 'Don Gibson',
#        'Wilma Lee Stoney Cooper', 'Wilburn Brothers', 'Hank Thompson',
#        'Kitty Wells', 'Faron Young', 'Rose Maddox', 'Eddy Arnold',
#        'Jimmy Martin', "James O'Gwynn", 'Bob Gallion', 'Hank Locklin',
#        'Buck Owens', 'Stonewall Jackson', 'Jeanne Black', 'Roy Drusky',
#        'Marty Robbins', 'Marion Worth', 'The Stanley Brothers',
#        'Lonnie Irving', 'Ernest', 'Claude Gray', 'Wynn Stewart',
#        'Elvis Presley', 'Sonny James', 'Charlie', 'Freddie Hart',
#        'Patsy Cline Jim Reeves', 'Hank Snow', 'Jimmy Newman',
#        'Moon Mullican', 'The Louvin Brothers', 'Warren Smith',
#        'Porter Wagoner', 'Ray Sanders', 'Reno Smiley', 'Cowboy Copas',
#        'Lewis Pruitt'], dtype=object)

# %% [markdown]
# ### Scraping Genuis API for Song Lyrics

# %%
import lyricsgenius
import random
import json
import requests
from fuzzywuzzy import fuzz
auth = 'gieHFE9rIVa4DNDzVPLH6Vcv17A2bLhABjl13Y4zJFkwdcuNRnZgxZWa3sz-DgbX'
#genius = lyricsgenius.Genius(genius_key)
oops = []
# Out:
# /Users/jessli/anaconda3/lib/python3.7/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# Genius API Requests
def request_song_info(song_title, artist_name):
    base_url = 'https://api.genius.com'
    headers = {'Authorization': 'Bearer ' + auth}
    search_url = base_url + '/search'
    data = {'q': song_title + ' ' + artist_name}
    response = requests.get(search_url, data=data, headers=headers)

    return response

# %%
def find_song_artist(song_title, artist_name, op):
    # Search for matches in the request response
    response = request_song_info(song_title, artist_name)
    json = response.json()
    remote_song_info = None
    for hit in json['response']['hits']:
        if (artist_name.lower() in hit['result']['primary_artist']['name'].lower()) or (fuzz.partial_ratio(artist_name.lower(),hit['result']['primary_artist']['name'].lower())>90):
            remote_song_info = hit
            break
    try:
        if remote_song_info:
            song_url = remote_song_info['result']['url']
        page = requests.get(song_url)
        html = BeautifulSoup(page.text, 'html.parser')
        lyrics = html.find('div', class_='lyrics').get_text()
        return lyrics
    except:
        print('exception: {}' +song_title + artist_name)
        return None

# %%
# Get the 
df['lyrics'] = df.apply(lambda x: find_song_artist(x['song'],x['artist'],oops), axis=1)
df.head()
# Out:
# exception: {}Poor Old Heartsick MeMargie
# exception: {}Come Walk With MeWilma Lee Stoney Cooper
# exception: {}Gambler's LoveRose Maddox
# exception: {}How Can I Think Of TomorrowJames O'Gwynn
# exception: {}You Take The Table And I'll Take The ChairsBob Gallion
# exception: {}That's My Kind Of LoveMarion Worth
# exception: {}Each Moment ('spent With You)Ernest
# exception: {}(Doin' The) Lovers LeapWebb Pierce
# exception: {}The Key's In The MailboxFreddie Hart
# exception: {}The Hand You're Holding NowSkeeter Davis
# exception: {}Everybody's Dying For LoveJimmy Newman
# exception: {}Ragged But RightMoon Mullican
# exception: {}Odds And Ends (Bits And Pieces)Warren Smith
# exception: {}LonelyvilleRay Sanders
# exception: {}Teach Me How To LieHank Thompson
# exception: {}Don't Let Your Sweet Love DieReno Smiley
# exception: {}Flat TopCowboy Copas
# exception: {}Crazy BullfrogLewis Pruitt
# exception: {}If A Woman Answers (Hang Up The Phone)Leroy Van Dyke
# exception: {}I Can Mend Your Broken HeartDon Gibson
# exception: {}Alla My LoveWebb Pierce
# exception: {}Just Ain'tFlatt Scruggs
# exception: {}My Name Is MudJames O'Gwynn
# exception: {}Crazy Wild DesireWebb Pierce
# exception: {}I Guess I'll Never LearnCharlie
# exception: {}The Best Dressed Beggar (In Town)Carl Smith
# exception: {}Act NaturallyBuck Owens Ringo Starr
# exception: {}The Man Who Robbed The Bank At Santa FeHank Snow
# exception: {}Don't Call Me From A Honky TonkJohnny A.
# exception: {}Pearl Pearl PearlFlatt Scruggs
# exception: {}Goodbye KissesCowboy Copas
# exception: {}The Only Girl I Can't ForgetDel Reeves
# exception: {}Please Talk To My HeartCountry Johnny Mathis
# exception: {}My Father's VoiceJudy Lynn
# exception: {}Shoes Of A FoolBill Goodwin
# exception: {}Cold And Lonely (Is The Forecast For Tonight)Kitty Wells
# exception: {}Rosebuds And YouBenny Martin
# exception: {}Your Mother's PrayerBuddy Cagle
# exception: {}One Among The ManyNed Miller
# exception: {}BaltimoreSonny James
# exception: {}Keeping Up With The JonesesFaron Young
# exception: {}Invisible TearsNed Miller
# exception: {}Followed Closely By My TeardropsHank Locklin
# exception: {}ChickashayDavid Houston
# exception: {}Looking For More In '64Jim Nesbitt
# exception: {}Keep Those Cards And Letters Coming InJohnny Jonie Mosby
# exception: {}Pick Of The WeekRoy Drusky
# exception: {}A Week In The CountryErnest
# exception: {}Memory #1Webb Pierce
# exception: {}Walkin'  Talkin'  Cryin'  Barely Beatin' Broken HeartJohnny Wright
# exception: {}When The World's On FireTillman Franks Singers
# exception: {}You Are My FlowerFlatt Scruggs
# exception: {}My Baby Walks All Over MeJohnny Sea
# exception: {}You Took Him Off My Hands (Now Please Take Him Off My Mind)Marion Worth
# exception: {}The First Step Down (Is The Longest)Bob Jennings
# exception: {}I Can Stand It (As Long As She Can)Bill Phillips
# exception: {}Angel On LeaveJimmy C. Newman
# exception: {}Summer Skies And Golden SandsJimmy C. Newman
# exception: {}Understand Your GalMargie
# exception: {}Slipping AroundMarion Worth George Morgan
# exception: {}Eight Years (And Two Children Later)Claude Gray
# exception: {}I'm A Walkin' Advertisement (For The Blues)Norma Jean
# exception: {}10 Little BottlesJohnny Bond
# exception: {}I've Got Five Dollars And It's Saturday NightGeorge Gene
# exception: {}My Old Faded RoseJohnny Sea
# exception: {}Just Thought I'd Let You KnowCarl Butler Pearl
# exception: {}Back In CirculationJimmy Newman
# exception: {}He Stands Real Tall'Little Jimmy Dickens'
# exception: {}Six Lonely HoursKitty Wells
# exception: {}Blame It On The MoonlightJohnny Wright
# exception: {}Forty Nine  Fifty OneHank Locklin
# exception: {}Gettin' Married Has Made Us StrangersDottie West
# exception: {}I Had One Too ManyWilburn Brothers
# exception: {}Too Many TigersTex Williams
# exception: {}Tippy ToeingThe Harden Trio
# exception: {}I'm Living In Two WorldsBonnie Guitar
# exception: {}Back Pocket MoneyJimmy Newman
# exception: {}Catch A Little RaindropClaude King
# exception: {}A Way To SurviveRay Price
# exception: {}Stop The Start (Of Tears In My Heart)Johnny Dollar
# exception: {}The Twelfth Of NeverSlim Whitman
# exception: {}Rainbows And RosesRoy Drusky
# exception: {}Don't Touch MeWilma Burgess
# exception: {}Tonight I'm Coming HomeBuddy Cagle
# exception: {}The Count DownHank Snow
# exception: {}Common Colds And Broken HeartsRay Pillow
# exception: {}I'll Leave The Singin' To The BluebirdsSheb Wooley
# exception: {}BraceroStu Phillips
# exception: {}Till My Getup Has Gotup And GoneErnest Tubb
# exception: {}Why Should I Cry Over YouFreddie Hart
# exception: {}Born To Be In Love With YouVan Trevor
# exception: {}One Bum TownDel Reeves
# exception: {}You Ain't No Better Than MeWebb Pierce
# exception: {}'The A Team'SSgt Barry Sadler
# exception: {}Sam's PlaceBuck Owens The Buckaroos
# exception: {}Sneaking 'Cross The BorderThe Harden Trio
# exception: {}Fifteen DaysWilma Burgess
# exception: {}Diesel On My TailJim Jesse
# exception: {}All My TomorrowsNat Stuckey
# exception: {}Both Sides Of The LineWanda Jackson
# exception: {}Roarin' AgainWilburn Brothers
# exception: {}The WatchmanClaude King
# exception: {}Ramblin' ManRay Pennington
# exception: {}Goodbye City  Goodbye GirlWebb Pierce
# exception: {}Back To Nashville  TennesseeStonemans
# exception: {}Conscience Keep An Eye On MeNorma Jean
# exception: {}You Can Steal MeBonnie Guitar
# exception: {}Row Row RowHenson Cargill
# exception: {}With Pen In HandJohnny Darrell
# exception: {}Mental JourneyLeon Ashley
# exception: {}Wild BloodDel Reeves
# exception: {}Will You Visit Me On Sundays?Charlie Louvin
# exception: {}What A Way To LiveJohnny Bush
# exception: {}Going Home For The Last TimeKenny Price
# exception: {}I've Been There BeforeRay Price
# exception: {}You Better Sit Down KidsRoy Drusky
# exception: {}He's A Good Ole BoyArlene
# exception: {}Ordinary MiracleBobby Lewis
# exception: {}Take Me Along With YouVan Trevor
# exception: {}Evolution And The BibleHugh X. Lewis
# exception: {}The Sunshine Of My WorldDallas Frazier
# exception: {}The Jimmie Rodgers BluesElton Britt
# exception: {}Live Your Life Out LoudBobby Lord
# exception: {}Sunshine And BluebirdsJimmy Newman
# exception: {}Mama SezMarion Worth
# exception: {}The Sugar From My CandyRay Griff
# exception: {}You Gave Me A MountainJohnny Bush
# exception: {}California Girl (And The Tennessee Square)Tompall The Glaser Brothers
# exception: {}Cajun BabyDoug Kershaw With Hank Williams  Jr.
# exception: {}Rings Of GoldDottie West
# exception: {}There's Better Things In LifeJerry Reed
# exception: {}Walkin' Back To BirminghamLeon Ashley
# exception: {}Let's Put Our World Back TogetherCharlie Louvin
# exception: {}Like A BirdGeorge Morgan
# exception: {}SolitaryDon Gibson
# exception: {}Sweet WineJohnny Carver
# exception: {}Make It RainBilly Mize
# exception: {}I'm A Good Man (In A Bad Frame Of Mind)Jack Reno
# exception: {}All For The Love Of A GirlClaude King
# exception: {}Just Enough To Start Me Dreamin'Jeannie Seely
# exception: {}Dusty RoadNorma Jean
# exception: {}Too Much Of A Man (To Be Tied Down)Arlene
# exception: {}Good Deal  LucilleCarl Smith
# exception: {}I Do My Swinging At HomeDavid Houston
# exception: {}She's A Little Bit CountryGeorge Hamilton IV
# exception: {}Lovin' Man (Oh Pretty Woman)Arlene
# exception: {}Lilacs And FireGeorge Morgan
# exception: {}I've Just Been Wasting My TimeJohn Wesley Ryles  I
# exception: {}You And Me Against The WorldBobby Lord
# exception: {}Tomorrow Never ComesSlim Whitman
# exception: {}All That Keeps Ya Goin'The Glaser Brothers
# exception: {}I'm Leavin' It Up To YouJohnny Jonie Mosby
# exception: {}The Most Uncomplicated Goodbye I've Ever HeardHenson Cargill
# exception: {}Down In New OrleansBuddy Alan
# exception: {}Sugar ShackBobby G. Rice
# exception: {}Old Man WillisNat Stuckey
# exception: {}You're Gonna Need A ManJohnny Duncan
# exception: {}A Good ThingBill Wilbourn Kathy Morrison
# exception: {}Warmth Of The WineJohnny Bush
# exception: {}Little Bit LateLewie Wickham
# exception: {}Pickin' Wild Mountain BerriesLawanda Lindsey
# exception: {}There's A Whole Lot About A Woman (A Man Don't Know)/Makin' Up His MindJack Greene
# exception: {}Angel's SundayJim Ed Brown
# exception: {}Let Me Live/Did You Think To PrayCharley Pride
# exception: {}Empty ArmsSonny James
# exception: {}Chip 'N' Dale's PlaceClaude King
# exception: {}Something Beautiful (To Remember)Slim Whitman
# exception: {}If You Love Me (Really Love Me)Lamar Morris
# exception: {}It's Time To Love HerBilly Walker
# exception: {}Working Like The Devil (For The Lord)Del Reeves
# exception: {}The World Needs A MelodyRed Lane
# exception: {}Married To A MemoryArlene
# exception: {}A Good ManJune Carter Cash
# exception: {}Next Time I Fall In Love (I Won't)Hank Thompson
# exception: {}Sunday Morning ChristianHARLAN
# exception: {}Charley's PicturePorter Wagoner
# exception: {}Make Me Your Kind Of WomanPatti Page
# exception: {}Then You Walk InSammi Smith
# exception: {}There's Something About A LadyJohnny Duncan
# exception: {}The Lonesomest Lonesome/That's What Leaving's AboutRay Price
# exception: {}Grandma Harp/Turnin' Off A MemoryMerle Haggard
# exception: {}Chantilly Lace/Think About It Darlin'Jerry Lee Lewis
# exception: {}Ain't Nothin' Shakin' (But The Leaves On The Trees)'Billy Crash Craddock'
# exception: {}KateJohnny Cash The Tennessee Three
# exception: {}Send Me Some Lovin'Hank Williams  Jr. Lois Johnson
# exception: {}I've Found Someone Of My OwnCal Smith
# exception: {}FoolsJohnny Duncan
# exception: {}My Hang-Up Is YouFreddie Hart
# exception: {}I'm The Man On Susie's MindGlenn Barber
# exception: {}Would You Want The World To EndMel Tillis
# exception: {}We Found It In Each Other's Arms/Sunny Side Of My LifeRoger Miller
# exception: {}Girl In New OrleansSammi Smith
# exception: {}Just Plain LonelyFerlin Husky
# exception: {}If You Ever Need My LoveJack Greene
# exception: {}You're EverythingTommy Cash
# exception: {}Travelin' Minstrel BandThe Carter Family
# exception: {}Need YouDavid Rogers
# exception: {}Anything's Better Than NothingMel Tillis
# exception: {}All His ChildrenCharley Pride with Henry Mancini
# exception: {}In The Spring (The Roses Always Turn Red)Dorsey Burnette
# exception: {}Love MeJeanne Pruett Marty Robbins
# exception: {}Bring It On Home (To Your Woman)Joe Stampley
# exception: {}Yellow RibbonJohnny Carver
# exception: {}Walk Softly On The BridgesMel Street
# exception: {}Sweet Country WomanJohnny Duncan
# exception: {}Honky Tonk WineWayne Kemp
# exception: {}You've Got Me (Right Where You Want Me)Connie Smith
# exception: {}Sound Of Goodbye/The Song Nobody SingsJerry Wallace
# exception: {}Too Much Monkey BusinessFreddy Weller
# exception: {}Say WhenDiana Trask
# exception: {}ChainedJohnny Russell
# exception: {}Come Early Morning/AmandaDon Williams
# exception: {}Just Thank MeDavid Rogers
# exception: {}Thank You For Being YouMel Tillis
# exception: {}Daisy May (And Daisy May Not)Terri Lane
# exception: {}Workin' On A Feelin'Tommy Cash
# exception: {}Loving YouTony Booth
# exception: {}The Fool I've Been TodayJack Greene
# exception: {}Just What I've Been Looking ForDottie West
# exception: {}Is It Wrong (For Loving You)Sonny James
# exception: {}Lean It All On MeDiana Trask
# exception: {}You Don't Need To Move A MountainJeanne Pruett
# exception: {}Stop The World (And Let Me Off)Susan Raye
# exception: {}Some Kind Of A WomanFaron Young
# exception: {}CapturedTerry Stafford
# exception: {}How Lucky Can One Man BeJoe Stampley
# exception: {}The Telephone CallTina Daddy
# exception: {}Country LullabyeJohnny Carver
# exception: {}(Jeannie Marie) You Were A LadyTommy Overstreet
# exception: {}That Same Ol' Look Of LoveDavid Houston
# exception: {}Born To Love And SatisfyKaren Wheeler
# exception: {}She's In Love With A Rodeo ManJohnny Russell
# exception: {}DallasConnie Smith
# exception: {}GoodbyeRex Allen Jr.
# exception: {}The PillowJohnny Duncan
# exception: {}Friend Named RedBrian Shaw
# exception: {}I Wanta Get To YouLa Costa
# exception: {}Brass BucklesBarbi Benton
# exception: {}From Barrooms To BedroomsDavid Wills
# exception: {}The Most Wanted Woman In TownRoy Head
# exception: {}I'd Like To Sleep Til I Get Over YouFreddie Hart
# exception: {}She Talked A Lot About TexasCal Smith
# exception: {}Mississippi You're On My MindStoney Edwards
# exception: {}Where He's Going  I've Already Been/The Kind Of Woman I GotHank Williams Jr.
# exception: {}(There She Goes) I Wish Her WellDon Gibson
# exception: {}HurtConnie Cato
# exception: {}ColindaFiddlin' Frenchie Burke The Outlaws
# exception: {}Fireball Rolled A SevenDave Dudley
# exception: {}Boilin' CabbageBill Black's Combo
# exception: {}Good News  Bad NewsEddy Raven
# exception: {}PersonalityPrice Mitchell Rene Sloane
# exception: {}She's Already GoneJim Mundy
# exception: {}Pictures On PaperJeris Ross
# exception: {}41st Street Lonely Hearts' Club/Weekend DaddyBuck Owens
# exception: {}The Devil In Mrs. JonesBilly Larkin
# exception: {}She'll Throw Stones At YouFreddie Hart
# exception: {}The Door Is Always OpenDave Rowland Sugar
# exception: {}America The Beautiful (1976)Charlie Rich
# exception: {}The Biggest Airport In The WorldMoe Bandy
# exception: {}Home Made LoveThom Bresh
# exception: {}Can You Hear Those PioneersRex Allen Jr.
# exception: {}I'd Just Be Fool EnoughFaron Young
# exception: {}On The ReboundDel Reeves Billie Jo Spears
# exception: {}I Really Had A Ball Last NightCarmol Taylor
# exception: {}When Something Is Wrong With My BabySonny James
# exception: {}Rocking In Rosalee's BoatNick Nixon
# exception: {}It's EnoughRonnie Prophet
# exception: {}The Rains Came/sugar Coated LoveFreddy Fender
# exception: {}Thank God She's MineFreddie Hart
# exception: {}Bluest Heartache Of The YearKenny Dale
# exception: {}Me And Millie (stompin' Grapes And Gettin' Silly)Ronnie Sessions
# exception: {}That's When The Lyin' Stops (and The Lovin' StartsPal Rakes
# exception: {}She's Long LeggedJoe Stampley
# exception: {}Born BelieverJim Ed Brown Helen Cornelius
# exception: {}A Passing ThingRay Griff
# exception: {}Silver BirdTina Rainford
# exception: {}Let Me Love You Once Before You GoBarbara Fairchild
# exception: {}Look Who I'm Cheating On Tonight/if You Think I'mBobby Bare
# exception: {}So Many WaysDavid Houston
# exception: {}Kentucky WomanRandy Barlow
# exception: {}If You Gotta Make A Fool Of SomebodyDickey Lee
# exception: {}Love's ExplosionMargo Smith
# exception: {}Red Wine And Blue MemoriesJoe Stampley
# exception: {}Night Time MagicLarry Gatlin The Gatlin Brothers
# exception: {}Gotta Quit Lookin' At You BabyDave Rowland Sugar
# exception: {}No  No  No (I'd Rather Be Free)Rex Allen Jr.
# exception: {}Puttin' In Overtime At HomeCharlie Rich
# exception: {}Georgia In A Jug/me And The IrsJohnny Paycheck
# exception: {}Slow And EasyRandy Barlow
# exception: {}Now You See 'em now You Don'tRoy Head
# exception: {}I Like Ladies In Long Black DressesBobby Borchers
# exception: {}Shady RestMel Street
# exception: {}Dirty WorkSterling Whipple
# exception: {}Here Comes The Reason I LiveRonnie McDowell
# exception: {}It's All Wrong but It's Alright/Two Doors DownDolly Parton
# exception: {}Baby  I'm Yours/God KnowsDebby Boone
# exception: {}I Can't Get Up By MyselfBrenda Kaye Perry
# exception: {}Weekend FriendCon Hunley
# exception: {}Unchained Melody/softly As I Leave YouElvis Presley
# exception: {}Rising Above It AllLynn Anderson
# exception: {}The LoserKenny Dale
# exception: {}I'll Never Be FreeJim Ed Brown Helen Cornelius
# exception: {}Born To Be With YouSandy Posey
# exception: {}Lying In Love With YouJim Ed Brown Helen Cornelius
# exception: {}Red Bandana/i Must Have Done Something BadMerle Haggard
# exception: {}Next Best FeelingMary K Miller
# exception: {}Rockin' My Life Away/i Wish I Was Eighteen AgainJerry Lee Lewis
# exception: {}Are You Sincere/solitaireElvis Presley
# exception: {}Two Steps Foward And Three Steps BackSusie Allanson
# exception: {}What In Her World Did I DoEddy Arnold
# exception: {}Down To Earth WomanKenny Dale
# exception: {}Just Like Real PeopleThe Kendalls
# exception: {}I Don't LieJoe Stampley
# exception: {}Lo Que Sea (whatever May The Future Be)Jess Garron
# exception: {}Steady As The RainStella Parton
# exception: {}Faded Love And Winter RosesDavid Houston
# exception: {}Touch Me (i'll Be Your Fool Once More)Big Al Downing
# exception: {}The Girl On The Other SideNick Noble
# exception: {}My Mama Never Heard Me Sing'Billy Crash Craddock'
# exception: {}World's Most Perfect WomanRonnie McDowell
# exception: {}Play Together Again AgainBuck Owens With Emmylou Harris
# exception: {}She's Been Keepin' Me Up NightsBobby Lewis
# exception: {}My Heart Is Not My OwnMundo Earwood
# exception: {}Moment By MomentNarvel Felts
# exception: {}I'll Never Let You DownTommy Overstreet
# exception: {}I Just Wanna Feel The MagicBobby Borchers
# exception: {}What A LieSammi Smith
# exception: {}On Business For The King/blue Ribbon BluesJoe Sun
# exception: {}May ITerri Hollowell
# exception: {}Isn't It Always LoveLynn Anderson
# exception: {}Spare A Little Lovin'(on A Fool)Arnie Rue
# exception: {}My Heart/silent Night(after The Fight)Ronnie Milsap
# exception: {}I'm Already BlueThe Kendalls
# exception: {}Tell Ole I Ain't Here  He Better Get On HomeMoe Bandy Joe Stampley
# exception: {}Your Body Is An OutlawMel Tillis
# exception: {}Too Old To Play CowboyRazzy Bailey
# exception: {}New York Wine And Tennessee ShineDave Rowland Sugar
# exception: {}Rodeo EyesZella Lehr
# exception: {}The ChampMoe Bandy
# exception: {}You're In Love With The Wrong ManMundo Earwood
# exception: {}Bar Room BuddiesMerle Haggard Clint Eastwood
# exception: {}I Can See Forever Loving YouFoxfire
# exception: {}It Don't Hurt To DreamSylvia
# exception: {}Shotgun RiderJoe Sun
# exception: {}You Fill My LifeJuice Newton
# exception: {}J.r.B.J. Wright
# exception: {}Morning Comes Too EarlyJim Ed Brown Helen Cornelius
# exception: {}It's OverRex Allen Jr.
# exception: {}Friends/Anywhere There's A JukeboxRazzy Bailey
# exception: {}What Are We Doin' In LoveDottie West w  Kenny Rogers
# exception: {}A Million Old GoodbyesMel Tillis
# exception: {}Lovin' Arms/You Asked Me ToElvis Presley
# exception: {}Do I Have To Draw A PictureBilly Swan
# exception: {}My Woman Loves The Devil Out Of MeMoe Bandy
# exception: {}I Want You TonightJohnny Rodriguez
# exception: {}Evil AngelEd Bruce
# exception: {}Love Dies HardRandy Barlow
# exception: {}Lovin' Her Was Easier (Than Anything I'll Ever Do Again)The Glaser Brothers
# exception: {}Getting Over You AgainRay Price
# exception: {}Does She Wish She Was Single AgainThe Burrito Brothers
# exception: {}You're Crazy ManFreddie Hart
# exception: {}Some Love Songs Never DieB.J. Thomas
# exception: {}Good Ol' GirlsSonny Curtis
# exception: {}Your Wife Is Cheatin' On Us AgainWayne Kemp
# exception: {}Learning To Live AgainBobby Bare
# exception: {}Fool By Your SideDave Rowland Sugar
# exception: {}Don't Bother To KnockJim Ed Brown Helen Cornelius
# exception: {}Just Like MeTerry Gregory
# exception: {}Bally Hoo DaysEddy Arnold
# exception: {}I Still Miss SomeoneDon King
# exception: {}Here's To The HorsesJohnny Russell
# exception: {}Footprints In The SandEdgel Groves
# exception: {}Just To Satisfy YouWaylon Willie
# exception: {}Just Give Me What You Think Is FairLeon Everette
# exception: {}Everytime You Cross My MindRazzy Bailey
# exception: {}I'm Goin' Hurtin'Joe Stampley
# exception: {}Forty And Fadin'Ray Price
# exception: {}Ashes To AshesTerri Gibbs
# exception: {}With Their Kind Of Money And Our Kind Of LoveBilly Swan
# exception: {}The Man With The Golden ThumbJerry Reed
# exception: {}I Think About Your Lovin'The Osmonds
# exception: {}Closer To YouThe Burrito Brothers
# exception: {}A Little Bit CrazyEddy Raven
# exception: {}When You Find Her  Keep HerWright Brothers
# exception: {}Round The Clock Lovin'Gail Davies
# exception: {}I Just Cut MyselfRonnie McDowell
# exception: {}(who's Gonna Sing)the Last Country SongBilly Parker
# exception: {}Slippin' And Slidin'Stephanie Winslow
# exception: {}You're Out Doing What I'm Here Doing WithoutGene Watson With The Farewell Party Band
# exception: {}In The Middle Of The NightMel Tillis
# exception: {}My Lady Loves Me (just As I Am)Leon Everette
# exception: {}Without YouT.G. Sheppard
# exception: {}Singing The BluesGail Davies
# exception: {}You Got Me RunningJim Glaser
# exception: {}More &amp; MoreCharley Pride
# exception: {}I Wonder Who's Holding My Baby TonightThe Whites
# exception: {}After The Great DepressionRazzy Bailey
# exception: {}You Can't Lose What You Never HadLynn Anderson
# exception: {}Once You Get The Feel Of ItCon Hunley
# exception: {}Don't Your Mem'ry Ever Sleep At NightSteve Wariner
# exception: {}You're Not Leavin' Here TonightEd Bruce
# exception: {}DenverLarry Gatlin The Gatlin Brothers
# exception: {}I Can Tell By The Way You Dance (You're Gonna Love Me TonighVern Gosdin
# exception: {}Victims Of GoodbyeSylvia
# exception: {}The Whole World's In Love When You're LonelyB.J. Thomas
# exception: {}I Still DoBill Medley
# exception: {}Better Our Hearts Should Bend (than Break)Bandana
# exception: {}Candy ManMickey Gilley Charly McClain
# exception: {}Memory LaneJoe Stampley Jessica Boucher
# exception: {}Born To Love YouKaren Brooks
# exception: {}Forever YouThe Whites
# exception: {}I Never Had A Chance With YouMason Dixon
# exception: {}When Givin' Up Was EasyEd Bruce
# exception: {}Maybe My BabyLouise Mandrell
# exception: {}If It Ain't Love (Let's Leave It Alone)The Whites
# exception: {}You're Going Out Of My MindT.G. Sheppard
# exception: {}To Be LoversChance
# exception: {}Save The Last ChanceJohnny Lee
# exception: {}Real LoveDolly Parton (Duet With Kenny Rogers)
# exception: {}Reno BoundSouthern Pacific
# exception: {}Partners  Brothers &amp; FriendsNitty Gritty Dirt Band
# exception: {}Back When Love Was EnoughMark Gray
# exception: {}Hey Doll BabySweethearts Of The Rodeo
# exception: {}CowpokeGlen Campbell
# exception: {}Savin' My Love For YouPake McEntire
# exception: {}True Love (Never Did Run Smooth)Tom Wopat
# exception: {}Strong HeartT.G. Sheppard
# exception: {}You Must Be Lookin' For MeBilly Swan
# exception: {}The Lights Of AlbuquerqueJim Glaser
# exception: {}Anything GoesGary Morris
# exception: {}Til' I'm Too Old To Die YoungMoe Bandy
# exception: {}You're Never Too Old For Young LoveEddy Raven
# exception: {}Chains Of GoldSweethearts Of The Rodeo
# exception: {}Have I Got Some Blues For YouCharley Pride
# exception: {}Can't Stop My Heart From Loving YouThe O'Kanes
# exception: {}Full Grown FoolMickey Gilley
# exception: {}American MeSchuyler  Knobloch Bickhardt
# exception: {}Oh HeartBaillie The Boys
# exception: {}Love Can't Ever Get Better Than ThisRicky Skaggs Sharon White
# exception: {}From Time To Time (It Feels Like Love Again)Larry Gatlin Janie Frickie
# exception: {}3935 West End AvenueMason Dixon
# exception: {}Midnight BlueJohn Wesley Ryles
# exception: {}Don't Let Go Of My HeartSouthern Pacific
# exception: {}Old FolksRonnie Milsap Mike Reid
# exception: {}Love Of A LifetimeLarry  Steve  Rudy: The Gatlin Brothers
# exception: {}Talkin' To The Wrong ManMichael Martin Murphey (with Ryan Murphey)
# exception: {}Texas In 1880Foster Lloyd
# exception: {}Your Memory Wins AgainSkip Ewing
# exception: {}Givers And TakersSchuyler  Knobloch Bickhardt
# exception: {}Steppin' OutDavid Ball
# exception: {}I'm Still Your FoolDavid Slater
# exception: {}The Gospel According To LukeSkip Ewing
# exception: {}Wine Me UpLarry Boone
# exception: {}I Know What I've GotJ.C. Crowley
# exception: {}Up And GoneThe McCarters
# exception: {}Don't Quit Me NowJames House
# exception: {}Like Father Like SonLionel Cartwright
# exception: {}If I Ever Go CrazyThe Shooters
# exception: {}You Ain't Going NowhereChris Hillman Roger McGuinn
# exception: {}If I Never See Midnight AgainSweethearts Of The Rodeo
# exception: {}Sea Of HeartbreakRonnie McDowell
# exception: {}Never Say NeverT. Graham Brown
# exception: {}She Deserves YouBaillie The Boys
# exception: {}I Might Be What You're Lookin' ForLarry Gatlin The Gatlin Brothers
# exception: {}Bring Back Your Love To MeEarl Thomas Conley
# exception: {}PerfectBaillie The Boys
# exception: {}Is It LoveFoster Lloyd
# exception: {}Back Where I Come FromMac McAnally
# exception: {}Rockin' YearsDolly Parton With Ricky Van Shelton
# exception: {}Till You Were GoneMike Reid
# exception: {}RestlessMark O'Connor The New Nashville Cats
# exception: {}Can I Count On YouMcBride The Ride
# exception: {}She's A NaturalRob Crosby
# exception: {}Neon MoonBrooks Dunn
# exception: {}Sacred GroundMcBride The Ride
# exception: {}The Power Of LoveMatthews  Wright King
# exception: {}Till I'm Holding You AgainPirates Of The Mississippi
# exception: {}Home Sweet HomeDennis Robbins
# exception: {}Still Got A Crush On YouDavis Daniel
# exception: {}Love On The Loose  Heart On The RunMcBride The Ride
# exception: {}We'll Burn That BridgeBrooks Dunn
# exception: {}If I Had A Cheatin' HeartRicky Lynn Gregg
# exception: {}Hard Workin' ManBrooks Dunn
# exception: {}That Ain't No Way To GoBrooks Dunn
# exception: {}They Don't Make 'Em Like That AnymoreBoy Howdy
# exception: {}Lifestyles Of The Not So Rich &amp; FamousTracy Byrd
# exception: {}Falling Out Of LoveJohn Audrey Wiggins
# exception: {}Little Miss Honky TonkBrooks Dunn
# exception: {}Get Over ItWoody Lee
# exception: {}My MariaBrooks Dunn
# exception: {}Circle Of FriendsDavid Ball
# exception: {}It's Your LoveTim McGraw With Faith Hill
# exception: {}Why Would I Say GoodbyeBrooks Dunn
# exception: {}A Dozen Red RosesTammy Graham
# exception: {}Drink  Swear  Steal &amp; LieMichael Peterson
# exception: {}Somewhere In LoveJohn Audrey Wiggins
# exception: {}Here's Your Sign (Get The Picture)Bill Engvall With Special Guest Travis Tritt
# exception: {}Papa BearKeith Harling
# exception: {}God Must Have Spent A Little More Time On YouAlabama Featuring 'N Sync
# exception: {}I Can't Get Over YouBrooks Dunn
# exception: {}South Of Santa FeBrooks Dunn
# exception: {}I Hope You DanceLee Ann Womack With Sons Of The Desert
# exception: {}Stuck In LoveThe Judds
# exception: {}You'll Always Be Loved By MeBrooks Dunn
# exception: {}Do I Love You EnoughRicochet
# exception: {}Ain't Nothing 'Bout YouBrooks Dunn
# exception: {}I'm Gonna Miss Her (The Fishin' Song)Brad Paisley
# exception: {}My Heart Is Lost To YouBrooks Dunn
# exception: {}Mendocino County LineWillie Nelson Duet With Lee Ann Womack
# exception: {}Chasin' AmyBrett James
# exception: {}Squeeze Me InGarth Brooks Duet With Trisha Yearwood
# exception: {}Real Bad MoodMarie Sisters
# exception: {}Beer For My HorsesToby Keith Duet With Willie Nelson
# exception: {}Red Dirt RoadBrooks Dunn
# exception: {}That's What She Gets For Loving MeBrooks Dunn
# exception: {}Save A Horse (Ride A Cowboy)Big Rich
# exception: {}Rough &amp; ReadyTrace Adkins
# exception: {}It's Getting Better All The TimeBrooks Dunn
# exception: {}Big TimeBig Rich
# exception: {}Politically UncorrectGretchen Wilson Featuring Merle Haggard
# exception: {}That's How They Do It In DixieHank Williams Jr. With Gretchen Wilson  Big Rich Van Zant
# exception: {}Never Mind MeBig Rich
# exception: {}Lost In This MomentBig Rich
# exception: {}I Got MoreCole Deggs The Lonesome
# exception: {}What You Give AwayVince Gill With Sheryl Crow
# exception: {}Last Good TimeFlynnville Train
# exception: {}Put A Girl In ItBrooks Dunn
# exception: {}Johnny &amp; JuneHeidi Newfield
# exception: {}RunawayLove Theft
# exception: {}Indian SummerBrooks Dunn
# exception: {}Address In The StarsCaitlin Will
# exception: {}Pray For YouJaron The Long Road To Love
# exception: {}Ain't No Stopping Her NowAsh Bowers
# exception: {}Angel EyesLove Theft
# exception: {}Marry MeMartina McBride Featuring Pat Monahan Of Train
# exception: {}Boys 'round HereBlake Shelton Featuring Pistol Annies Friends
# exception: {}Ho HeyLennon Maisy
# exception: {}HeavenJake Worthington
# exception: {}It Ain't Yours To Throw AwaySam Palladio
# exception: {}Good Ol' BoysJake Worthington
# exception: {}Sunshine &amp; WhiskeyFrankie Ballard
# exception: {}Look At YouBig Rich
# exception: {}Gunpowder And LeadKristen Merlin
# exception: {}A Life That's GoodLennon Maisy
# exception: {}Diamond Rings And Old BarstoolsTim McGraw With Catherine Dunn
# exception: {}Young &amp; CrazyFrankie Ballard
# exception: {}Tennessee WhiskeyMeghan Linsey
# exception: {}FlyMaddie Tae
# exception: {}I Will Never Let You KnowClare Bowen Sam Palladio
# exception: {}Huntin'  Fishin' &amp; Lovin' Every DayLuke Bryan
# exception: {}Think Of YouChris Young Duet With Cassadee Pope
# exception: {}Love Has No PrideAdam Wakefield
# exception: {}My ChurchMary Sarah
# exception: {}Lovin' LatelyBig Rich Featuring Tim McGraw
# exception: {}Speak To A GirlTim McGraw Faith Hill
# exception: {}Tell Me WhyLauren Duski
# exception: {}AnywayBrennley Brown
# exception: {}Three Chords &amp; The TruthChase Rice
# exception: {}Brand New ManBrooks Dunn With Luke Combs
#           artist  rank                       song  year  \
# 0  Johnny Horton     1  The Battle Of New Orleans  1959
# 1   George Jones     2            White Lightning  1959
# 2     Jim Reeves     3                       Home  1959
# 3  George Morgan     4          I'm In Love Again  1959
# 4      Ray Price     5   Heartaches By The Number  1959
#
#                                               lyrics
# 0  \n\n[Verse 1]\nIn 1814 we took a little trip\n...
# 1  \n\nWell, in North Carolina, way back in the h...
# 2  \n\nWell, I've been a traveler most of my life...
# 3  \n\nNot so long ago I had my poor heart broken...
# 4  \n\nHeartache number one was when you left me\...

# %%
### clean a lyric string
def clean(text):    
    text = text.split('\n') # split string into lines
    text = [i for i in text if i] # drop missing lines
    text = [i for i in text if i[0]!='['] # drop bracketed lines (e.g. producer info, song part indicators)
    text = ' '.join(text) # join back into single string
    text = re.sub(r'[^\s\w]+', '', text) # filter out non-alpha-numeric characters 
    text = text.lower() # strip capitalization
    text = ' '.join([i for i in text.split()]) # drop stopwords
    return text

# %% [markdown]
# ### Scraping densities of locations of artists' birthtowns
